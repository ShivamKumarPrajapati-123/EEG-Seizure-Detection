# %%
from pathlib import Path
import pandas as pd
import numpy as np

PROJECT_ROOT = Path.cwd().parent

RESULTS_DIR = PROJECT_ROOT / "results"

print("RESULTS DIRECTORY:")
print(RESULTS_DIR)

print("\nAVAILABLE RESULT FILES:\n")

for file in sorted(RESULTS_DIR.glob("*")):
    print(file.name)
# Out:
# RESULTS DIRECTORY:
# C:\Users\Prajapati_Shivam\EEG-Seizure-Detection\results
#
# AVAILABLE RESULT FILES:
#
# confusion_matrix.png
# experiment_01_baseline_evaluation.txt
# experiment_02_recording_wise_confusion_matrix.png
# experiment_02_recording_wise_evaluation.txt
# experiment_03_class_imbalance_confusion_matrix.png
# experiment_03_class_imbalance_evaluation.txt
# experiment_04_threshold_comparison.csv
# experiment_04_threshold_optimization.txt
# experiment_04_threshold_performance.png
# experiment_06_cross_validation_report.txt
# experiment_comparison_summary.csv
# feature_importance.png
# final_evaluation.txt
# final_event_level_summary.csv
# final_experiment_performance_comparison.png
# final_integrated_experiment_comparison.csv
# final_integrated_metrics.csv
# final_integrated_performance_comparison.png
# final_integrated_research_conclusion.txt
# final_recording_wise_cross_validation_comparison.png
# final_temporal_consecutive_window_results.csv
# final_threshold_optimization_tradeoff.png
# notebook03_all_code.txt
# notebook06_all_code.txt
# notebook07_all_code.txt
# notebook08_all_code.txt
# notebook09_all_code.txt
# notebook11_all_code.txt
# notebook13_all_code.txt
# notebook14_all_code.txt
# phase2_final_event_level_results.csv
# phase2_final_temporal_results.csv
# phase2_internal_validation_thresholds.csv
# phase2_selected_threshold.txt
# phase3_final_results_master_table.csv
# threshold_analysis.png

# %%
master_path = (
    RESULTS_DIR /
    "phase3_final_results_master_table.csv"
)

master_df = pd.read_csv(master_path)

print("MASTER RESULTS TABLE")
display(master_df)
# Out:
# MASTER RESULTS TABLE
#                              Evaluation_Level                    Model  \
# 0                                     Dataset                  Dataset
# 1                  Recording-Wise Unseen Test  random_forest_final.pkl
# 2                                Window-Level  random_forest_final.pkl
# 3  Temporal Confirmation (3 windows / 12 sec)  random_forest_final.pkl
# 4  Temporal Confirmation (5 windows / 20 sec)  random_forest_final.pkl
# 5                                 Event-Level  random_forest_final.pkl
#
#    Threshold  Accuracy  Precision  Sensitivity  Specificity  F1_Score  \
# 0        NaN       NaN        NaN          NaN          NaN       NaN
# 1        0.5  0.998600   1.000000     0.917800     1.000000  0.957100
# 2        0.5  0.998600   1.000000     0.917800     1.000000  0.957100
# 3        0.5  0.998087   0.911392     0.986301     0.998296  0.947368
# 4        0.5  0.999043   1.000000     0.945205     1.000000  0.971831
# 5        0.5       NaN        NaN     1.000000          NaN       NaN
#
#    Balanced_Accuracy  True_Negatives  False_Positives  False_Negatives  \
# 0                NaN             NaN              NaN              NaN
# 1           0.958900          4108.0              0.0              6.0
# 2           0.958900          4108.0              0.0              6.0
# 3           0.992299          4101.0              7.0              1.0
# 4           0.972603          4108.0              0.0              4.0
# 5                NaN             NaN              NaN              0.0
#
#    True_Positives
# 0             NaN
# 1            67.0
# 2            67.0
# 3            72.0
# 4            69.0
# 5             3.0

# %%
temporal_path = (
    RESULTS_DIR /
    "phase2_final_temporal_results.csv"
)

temporal_df = pd.read_csv(
    temporal_path
)

print("TEMPORAL RESULTS")
display(temporal_df)
# Out:
# TEMPORAL RESULTS
#    consecutive_windows  confirmation_time_seconds  accuracy  precision  \
# 0                    1                          4  0.988280   0.600000
# 1                    2                          8  0.996173   0.827586
# 2                    3                         12  0.998087   0.911392
# 3                    5                         20  0.999043   1.000000
#
#    sensitivity  specificity  f1_score  balanced_accuracy    TN  FP  FN  TP
# 0     0.986301     0.988315  0.746114           0.987308  4060  48   1  72
# 1     0.986301     0.996349  0.900000           0.991325  4093  15   1  72
# 2     0.986301     0.998296  0.947368           0.992299  4101   7   1  72
# 3     0.945205     1.000000  0.971831           0.972603  4108   0   4  69

# %%
event_path = (
    RESULTS_DIR /
    "phase2_final_event_level_results.csv"
)

event_df = pd.read_csv(
    event_path
)

print("EVENT-LEVEL RESULTS")
display(event_df)
# Out:
# EVENT-LEVEL RESULTS
#    threshold  consecutive_windows  confirmation_time_seconds  \
# 0       0.05                    3                         12
#
#    seizure_containing_recordings  detected_seizure_events  \
# 0                              3                        3
#
#    missed_seizure_events  event_level_sensitivity
# 0                      0                      1.0
